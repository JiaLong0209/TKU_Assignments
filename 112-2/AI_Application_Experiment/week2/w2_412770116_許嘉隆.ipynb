# %%
# !pip install requests
# !pip install beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup
ptt_host = 'https://www.ptt.cc'
ptt_url = 'https://www.ptt.cc/bbs/Gossiping/index.html'

# %%
web = requests.get(ptt_url)
print(web.status_code)
print(web.text)
# Out:
# 200
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div class="bbs-screen bbs-content">
#     <div class="over18-notice">
#         <p>本網站已依網站內容分級規定處理</p>
#
#         <p>警告︰您即將進入之看板內容需滿十八歲方可瀏覽。</p>
#
#         <p>若您尚未年滿十八歲，請點選離開。若您已滿十八歲，亦不可將本區之內容派發、傳閱、出售、出租、交給或借予年齡未滿18歲的人士瀏覽，或將本網站內容向該人士出示、播放或放映。</p>
#     </div>
# </div>
#
# ...

# %%
params = {
    'name': "Python",
    'age': '18'

}
url = 'https://script.google.com/macros/s/AKfycbw5PnzwybI_VoZaHz65TpA5DYuLkxIF-HUGjJ6jRTOje0E6bVo/exec'
web = requests.get(url, params= params)
print(web)
print(web.text)
# Out:
# <Response [200]>
# 你的名字是：Python，年紀：18 歲。

# %%
cookies = {'over18': '1'}
web = requests.get(ptt_url, cookies = cookies)
print(web.text)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# ...

# %%
cookies = {'over18': '1'}
web = requests.get(ptt_url, cookies = cookies)
soup = BeautifulSoup(web.text, "html.parser")

res = soup.select('.title a')
for i in res:
    print(i.get_text())
# Out:
# Re: [問卦] 台灣撞死人代價低到離譜，連和解都免
# [問卦] 自住房房價上漲能幹嘛
# [問卦] 學測放榜了 好快
# Re: [新聞] 代理孕母將合法？公聽會明登場 各界立
# [問卦] 真的有很多文組碩士畢業後在啃老嗎?
# [問卦] 這次感冒到底是怎樣啦
# [問卦] 窮人被當成是有錢人有什麼感覺？
# Re: [問卦] 越南落後國家可以打造出富國島，台灣?
# [新聞] 批林右昌故意不登記模糊產權 謝國樑直指O
# [公告] 八卦板板規(2023.11.11)
# [協尋] 2/6 下午2點行忠行善交叉路口行車紀錄
# [公告] 板主徵選投票請按V開始捏&手機投票教學
# [協尋] 113/2/20萬華艋舺大道行車紀錄
# [協尋] 2/21 上午桃園南昌路與富昌街口行車紀

# %%
cookies = {'over18': '1'}
web = requests.get(ptt_url, cookies = cookies)
soup = BeautifulSoup(web.text, "html.parser")

res = soup.select('.r-ent')
res_find = soup.find_all('div', class_='r-ent')

print(type(soup))
print(type(res))
print(type(res_find))

for i in res_find:
    a = i.find_all('a')
    for index,j in enumerate(a):
        if(index == 0):
            text = j.get_text()
        elif(index == 2):
            name = j.get_text()[6:-4]
    href = a[0]['href']
    print(name)
    print(text)
    print(ptt_host + href)
# Out:
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# ray90910
# [問卦] 小朋友不體罰到底要怎麼教啊？
# https://www.ptt.cc/bbs/Gossiping/M.1709015308.A.D5C.html
# sheng1300905
# [新聞] 侵權53個頻道！陳建州愛看的安博盒子　負
# https://www.ptt.cc/bbs/Gossiping/M.1709015313.A.06B.html
# k232
# [問卦] 蘇慧倫謝金燕陳美鳳誰是演藝圈真正美魔女
# https://www.ptt.cc/bbs/Gossiping/M.1709015348.A.AFC.html
# leon131417
# [問卦] 震撼彈 王剛師傅 b站解禁了
# https://www.ptt.cc/bbs/Gossiping/M.1709015416.A.B5A.html
# w510048
# [問卦] 企業最愛大學的調查都怎麼來的?
# https://www.ptt.cc/bbs/Gossiping/M.1709015548.A.463.html
# zoeapezoo
# [新聞] M痘甫宣布消除就破功 中南部新增今年首2
# https://www.ptt.cc/bbs/Gossiping/M.1709015717.A.564.html
# moebius2
# Re: [問卦] 習包子怎麼做到把中國房價打到骨折？
# https://www.ptt.cc/bbs/Gossiping/M.1709015721.A.0EF.html
# TomFord5566
# [問卦] 穿alo在台灣會顯得很潮嗎？
# https://www.ptt.cc/bbs/Gossiping/M.1709015736.A.6CE.html
# CRAM1234
# Re: [問卦] uber eat是不是快倒了
# https://www.ptt.cc/bbs/Gossiping/M.1709015798.A.97E.html
# pipiboygay
# [問卦] 亞尼克董事長無奈:兩年請不到人當店長
# ...

# %%
import json
stu1 = {'name': 'Linux', 'id': 1, 'age': 18}
stu2 = {'name': 'Unix', 'id': 2, 'age': 19}
room = [stu1, stu2]

print(room)
with open('output.json', 'w') as f:
    json.dump(room, f, ensure_ascii=False, indent = 4)
# Out:
# [{'name': 'Linux', 'id': 1, 'age': 18}, {'name': 'Unix', 'id': 2, 'age': 19}]

# %%
with open('output.json') as f:
    room = json.load(f)
    print('classroom = ', room)
    for i in room:
        print(i)
# Out:
# classroom =  [{'name': 'Linux', 'id': 1, 'age': 18}, {'name': 'Unix', 'id': 2, 'age': 19}]
# {'name': 'Linux', 'id': 1, 'age': 18}
# {'name': 'Unix', 'id': 2, 'age': 19}

# %%
web = requests.get(ptt_url, cookies=cookies)
soup = BeautifulSoup(web.text, 'html.parser')
cookies = {'over18': '1'}

terms = ['title', 'link', 'id', 'time']
content = {i: '' for i in terms}
articles = soup.find_all('div', class_='r-ent')
fun = [lambda i: i.find('a').get_text(), lambda i: ptt_host + i.find('a')['href'],  lambda i: i.find('div', class_="author").get_text(), lambda i: i.find('div', class_='date').get_text()]
page = []

for i in articles:
    for x, t in enumerate(terms):  content[t] = fun[x](i)
    content = {i: '' for i in terms}
    page.append(content)

for i in page:
    print(i)

with open('w2.json', 'w', encoding='UTF-8') as f:
    json.dump(page, f, ensure_ascii=False, indent=4)
# Out:
# {'title': 'Re: [新聞] 監院指社宅興建效率不彰\u3000租金2萬至4萬5', 'link': 'https://www.ptt.cc/bbs/Gossiping/M.1709018217.A.962.html', 'id': 'andre9', 'time': ' 2/27'}
# {'title': '[新聞] 蔡英文財產曝光！存款6298萬\u3000選舉補助', 'link': 'https://www.ptt.cc/bbs/Gossiping/M.1709018306.A.DBC.html', 'id': 's7166945', 'time': ' 2/27'}
# {'title': '[問卦] 如果中國要求割讓金馬換取停戰 你同意嗎', 'link': 'https://www.ptt.cc/bbs/Gossiping/M.1709018320.A.80E.html', 'id': 'YOYOISGOOD', 'time': ' 2/27'}
# {'title': '[問卦] 學測考爆了啦 怎麼辦', 'link': 'https://www.ptt.cc/bbs/Gossiping/M.1709018331.A.569.html', 'id': 'Imotucc', 'time': ' 2/27'}
# {'title': '[問卦] 為什麼悟天克斯可以變身超三 達爾不行？', 'link': 'https://www.ptt.cc/bbs/Gossiping/M.1709018346.A.ED0.html', 'id': 'f77928', 'time': ' 2/27'}
# {'title': 'Re: [新聞] 疑似「談不下去」！海巡長官全撤離返台', 'link': 'https://www.ptt.cc/bbs/Gossiping/M.1709018370.A.53C.html', 'id': 'xzcb2008', 'time': ' 2/27'}
# ...
