# %%
import numpy as np
import matplotlib.pyplot as plt

def apply_sobel(image, kernel):
    """對圖像應用Sobel核"""
    kernel_height, kernel_width = kernel.shape
    image_height, image_width = image.shape

    # 計算卷積输出的尺寸
    output_height = image_height - kernel_height + 1
    output_width = image_width - kernel_width + 1

    # 初始化输出图像
    output = np.zeros((output_height, output_width))

    # 應用Sobel核
    for i in range(output_height):
        for j in range(output_width):
            output[i, j] = np.sum(image[i:i+kernel_height, j:j+kernel_width] * kernel).clip(0, 255)

    return output

def show_sobel_result(filename, show_edge_xy=False):
    # 讀取圖像
    image = plt.imread(filename)

    # 如果是彩色圖像，轉換成灰度圖
    if image.ndim == 3:
        image = image.mean(axis=2)

    # 定義Sobel核
    sobel_x = np.array([[-1, 0, 1], [-2, 0, 2], [-1, 0, 1]])
    sobel_y = np.array([[-1, -2, -1], [0, 0, 0], [1, 2, 1]])

    # 應用Sobel核
    edge_x = apply_sobel(image, sobel_x)
    edge_y = apply_sobel(image, sobel_y)

    # 計算梯度幅度
    magnitude = np.sqrt(edge_x**2 + edge_y**2).clip(0, 255)
    print(magnitude.max())

    # 顯示結果
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1), plt.imshow(image, cmap='gray'), plt.title('Original')
    plt.subplot(1, 2, 2), plt.imshow(magnitude, cmap='gray'), plt.title('Sobel Edge Detection')
    plt.show()

    if show_edge_xy:

        # 顯示結果
        plt.figure(figsize=(12, 6))
        plt.subplot(1, 2, 1), plt.imshow(edge_x**2, cmap='gray'), plt.title('edge_x')
        plt.subplot(1, 2, 2), plt.imshow(edge_y**2, cmap='gray'), plt.title('edge_y')
        plt.show()

# %%
show_sobel_result("./Osaka.bmp", True)
# Out:
# 255.0

# %%
show_sobel_result("./img1.jpg", True)
# Out:
# 255.0

# %%
show_sobel_result("./img2.jpg", True)
# Out:
# 255.0

# %%
import numpy as np
import matplotlib.pyplot as plt

def apply_sobel(image, kernel):
    """對圖像應用Sobel核"""
    kernel_height, kernel_width = kernel.shape
    image_height, image_width = image.shape

    # 計算卷積输出的尺寸
    output_height = image_height - kernel_height + 1
    output_width = image_width - kernel_width + 1

    # 初始化输出图像
    output = np.zeros((output_height, output_width))

    # 應用Sobel核
    for i in range(output_height):
        for j in range(output_width):
            output[i, j] = np.sum(image[i:i+kernel_height, j:j+kernel_width] * kernel).clip(0, 255)

    return output

def show_sobel_result(filename, show_edge_xy=False):
    # 讀取圖像
    image = plt.imread(filename)

    # 如果是彩色圖像，轉換成灰度圖
    if image.ndim == 3:
        image = image.mean(axis=2)

    # 定義Sobel核
    sobel_x = np.array([[-1, 0, 1], [-2, 0, 2], [-1, 0, 1]])
    sobel_y = np.array([[-1, -2, -1], [0, 0, 0], [1, 2, 1]])

    # 應用Sobel核
    edge_x = apply_sobel(image, sobel_x)
    edge_y = apply_sobel(image, sobel_y)

    # 計算梯度幅度
    # magnitude = np.sqrt(edge_x**2 + edge_y**2)
    magnitude = (edge_x + edge_y) / 2

    # 顯示結果
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1), plt.imshow(image, cmap='gray'), plt.title('Original')
    plt.subplot(1, 2, 2), plt.imshow(magnitude, cmap='gray'), plt.title('Sobel Edge Detection')
    plt.show()

    if show_edge_xy:

        # 顯示結果
        plt.figure(figsize=(12, 6))
        plt.subplot(1, 2, 1), plt.imshow(edge_x**2, cmap='gray'), plt.title('edge_x')
        plt.subplot(1, 2, 2), plt.imshow(edge_y**2, cmap='gray'), plt.title('edge_y')
        plt.show()

# %%
show_sobel_result("./Osaka.bmp", True)
